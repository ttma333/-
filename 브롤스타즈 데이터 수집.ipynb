# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
pip install brawlstats
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 71.3 MB/s eta 0:00:00
# ...
#   Created wheel for brawlstats: filename=brawlstats-4.1.1-py3-none-any.whl size=10578 sha256=528bebc47f5a597966c3bf25670da949d1c5c24c8c295b997a980b187c0af9fd
#   Stored in directory: /root/.cache/pip/wheels/89/4e/2f/bce4e808284cbb3b29709fd3bd2a05651ac0432717f81d6977
# Successfully built brawlstats
# ...

# %%
# 코랩 IP 확인
# !curl ipecho.net/plain
# Out:
# 35.204.87.250

# %%
import brawlstats
from pathlib import Path

token = open(Path('/gdrive/MyDrive/브롤스타즈분석/colab_token.txt')).read().strip()

# %%
# 클래스 객체화
client = brawlstats.Client(token)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-5-83454882e55d> in <module>
#       1 # 클래스 객체화
# ----> 2 client = brawlstats.Client(token)
#
# /usr/local/lib/python3.8/dist-packages/brawlstats/core.py in __init__(self, token, session, timeout, is_async, **options)
#      74             self.loop.create_task(self.__ainit__())
#      75         else:
# ---> 76             brawlers_info = self.get_brawlers()
#      77             self.api.set_brawlers(brawlers_info)
#      78
#
# /usr/local/lib/python3.8/dist-packages/brawlstats/core.py in get_brawlers(self, use_cache)
#     380             A list of available brawlers and information about them.
#     381         """
# --> 382         return self._get_model(self.api.BRAWLERS, model=Brawlers)
#
# /usr/local/lib/python3.8/dist-packages/brawlstats/core.py in _get_model(self, url, model, use_cache, key)
# ...

# %%
# 개인 유저 배틀로그
tag = "YR2J2QUL"

battles = client.get_battle_logs(tag)

battles[0].keys() # dict_keys(['battle_time', 'event', 'battle'])
battles[0]['event'] # Box({'id': 15000034, 'mode': 'duoShowdown', 'map': 'Skull Creek'})

battle = battles[0]['battle']
battle.keys() # dict_keys(['mode', 'type', 'rank', 'trophy_change', 'teams'])
battle['teams']

len(battle['teams']) # 5
battle['teams'][1]
# Out:
# BoxList([{'tag': '#PLL88QPC0', 'name': 'julyan7780', 'brawler': {'id': 16000034, 'name': 'JACKY', 'power': 7, 'trophies': 332}}, {'tag': '#PVPG9V8RP', 'name': 'Айна', 'brawler': {'id': 16000029, 'name': 'BEA', 'power': 7, 'trophies': 337}}, {'tag': '#P2LR9GG8L', 'name': 'ROBERTO', 'brawler': {'id': 16000045, 'name': 'STU', 'power': 8, 'trophies': 327}}])

# %%
# 랭커 데이터 수집 (1~200위)
rankers = client.get_rankings(ranking='players')
len(rankers)
# Out:
# 200

# %%
# 랭킹 1위 유저 태그
ranker1 = rankers[0]
ranker1_tag = ranker1['tag'].split("#")[1]

# %%
# 랭킹 1위 유저 배틀로그 (최근 25회 게임)
ranker1_battles = client.get_battle_logs(ranker1_tag)
battle1 = ranker1_battles[0]

# %%
battle1['battle'].keys()
# Out:
# dict_keys(['mode', 'type', 'result', 'duration', 'trophy_change', 'star_player', 'teams'])

# %% [markdown]
# 이 기록은 브롤 스타즈 전투 기록의 첫 번째에 대응됩니다. <Box>형태로 되어 있는 전투 기록을 살펴보면 다음의 내용을 포함하고 있습니다.
#
# battle_time: 전투 시간 (UTC +0:00)
# event: 게임 모드의 정보
# id: 게임 모드의 id
# mode: 게임 모드
# map: 젬 그랩의 맵
# battle: 전투 기록
# mode: 게임 모드
# type: 게임 타입
# result: victory (승)/defeat (패)
# duration: 게임 지속 시간 (초)
# trophy_change: 게임 결과로 인한 내 캐릭터의 트로피 변화
# star_player: 스타플레이어, 이긴 팀에서 1명 뽑힘
# tag: 스타플레이어의 태그
# name: 스타플레이어의 이름
# brawler: 스타플레이어의 브롤러
# teams: 팀 정보
# 우리 팀
# 팀원 1
# 팀원 2
# 팀원 3
# 상대 팀
# 팀원 4
# 팀원 5
# 팀원 6
